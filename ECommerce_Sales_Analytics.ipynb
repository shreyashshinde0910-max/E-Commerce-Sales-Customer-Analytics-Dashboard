# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customers = pd.read_csv(r"D:\Live Data\Downloads\Ecommerce_Dataset\Customers.csv")

products = pd.read_csv(r"D:\Live Data\Downloads\Ecommerce_Dataset\Products.csv")

orders = pd.read_csv(r"D:\Live Data\Downloads\Ecommerce_Dataset\Orders.csv")

# %%
customers.head()
# Out:
#   Customer_ID Customer_Name  Gender  Age               Email       Phone  \
# 0      C00001    Customer 1    Male   22  customer1@mail.com  9677280546
# 1      C00002    Customer 2  Female   22  customer2@mail.com  9362298393
# 2      C00003    Customer 3  Female   57  customer3@mail.com  9966616964
# 3      C00004    Customer 4  Female   60  customer4@mail.com  9211225158
# 4      C00005    Customer 5    Male   35  customer5@mail.com  9402533494
#
#        Segment   Join_Date       City        State
# 0     Consumer  2023-06-03       Pune  Maharashtra
# 1    Corporate  2022-10-19  Ahmedabad      Gujarat
# 2  Home Office  2023-06-26     Mysuru    Karnataka
# 3     Consumer  2022-09-28     Nagpur  Maharashtra
# 4  Home Office  2022-08-04     Mumbai  Maharashtra

# %%
products.head()
# Out:
#   Product_ID           Product_Name   Brand     Category   Sub_Category  Cost  \
# 0      P0001  Mobile Phones Model 1  BrandB  Electronics  Mobile Phones  1112
# 1      P0002  Mobile Phones Model 2  BrandC  Electronics  Mobile Phones  2206
# 2      P0003  Mobile Phones Model 3  BrandC  Electronics  Mobile Phones  1039
# 3      P0004  Mobile Phones Model 4  BrandA  Electronics  Mobile Phones   912
# 4      P0005  Mobile Phones Model 5  BrandA  Electronics  Mobile Phones   444
#
#    Selling_Price
# 0        1291.32
# 1        2758.48
# 2        1511.24
# 3        1291.14
# 4         529.32

# %%
orders.head()
# Out:
#    Order_ID  Order_Date Customer_ID Product_ID     Category   Sub_Category  \
# 0    100001  2023-04-20      C00677      P0025  Electronics     Headphones
# 1    100002  2023-05-24      C00499      P0011  Electronics  Mobile Phones
# 2    100003  2024-02-03      C00738      P0076    Furniture          Chair
# 3    100004  2023-01-17      C00316      P0064      Fashion          Jeans
# 4    100005  2023-05-02      C00346      P0093    Furniture           Sofa
#
#              Product_Name  Quantity  Unit_Price  Discount     Sales   Cost  \
# 0      Headphones Model 3         3     5264.53        15  13424.55  11958
# 1  Mobile Phones Model 11         4     3020.64         5  11478.43   9904
# 2          Chair Model 10         2     3369.65        15   5728.40   4962
# 3           Jeans Model 9         5      854.56        15   3631.88   3410
# 4            Sofa Model 5         1     4222.25        15   3588.91   3507
#
# ...

# %%
print("Customers:", customers.shape)
print("Orders:", orders.shape)
print("Products:", products.shape)
# Out:
# Customers: (1000, 10)
# Orders: (5000, 19)
# Products: (99, 7)

# %% [markdown]
# **#Checking column names**

# %%
print(customers.columns)
print(products.columns)
print(orders.columns)
# Out:
# Index(['Customer_ID', 'Customer_Name', 'Gender', 'Age', 'Email', 'Phone',
#        'Segment', 'Join_Date', 'City', 'State'],
#       dtype='str')
# Index(['Product_ID', 'Product_Name', 'Brand', 'Category', 'Sub_Category',
#        'Cost', 'Selling_Price'],
#       dtype='str')
# Index(['Order_ID', 'Order_Date', 'Customer_ID', 'Product_ID', 'Category',
#        'Sub_Category', 'Product_Name', 'Quantity', 'Unit_Price', 'Discount',
#        'Sales', 'Cost', 'Profit', 'Region', 'State', 'City', 'Payment_Method',
#        'Shipping_Mode', 'Delivery_Days'],
#       dtype='str')

# %% [markdown]
# **#Checking data types**

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer_ID    1000 non-null   str
#  1   Customer_Name  1000 non-null   str
#  2   Gender         1000 non-null   str
#  3   Age            1000 non-null   int64
#  4   Email          1000 non-null   str
#  5   Phone          1000 non-null   int64
#  6   Segment        1000 non-null   str
#  7   Join_Date      1000 non-null   str
#  8   City           1000 non-null   str
#  9   State          1000 non-null   str
# dtypes: int64(2), str(8)
# memory usage: 78.3 KB

# %%
products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product_ID     99 non-null     str
#  1   Product_Name   99 non-null     str
#  2   Brand          99 non-null     str
#  3   Category       99 non-null     str
#  4   Sub_Category   99 non-null     str
#  5   Cost           99 non-null     int64
#  6   Selling_Price  99 non-null     float64
# dtypes: float64(1), int64(1), str(5)
# memory usage: 5.5 KB

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        5000 non-null   int64
#  1   Order_Date      5000 non-null   str
#  2   Customer_ID     5000 non-null   str
#  3   Product_ID      5000 non-null   str
#  4   Category        5000 non-null   str
#  5   Sub_Category    5000 non-null   str
#  6   Product_Name    5000 non-null   str
#  7   Quantity        5000 non-null   int64
#  8   Unit_Price      5000 non-null   float64
#  9   Discount        5000 non-null   int64
#  10  Sales           5000 non-null   float64
#  11  Cost            5000 non-null   int64
#  12  Profit          5000 non-null   float64
#  13  Region          5000 non-null   str
#  14  State           5000 non-null   str
#  15  City            5000 non-null   str
#  16  Payment_Method  5000 non-null   str
#  17  Shipping_Mode   5000 non-null   str
# ...

# %% [markdown]
# **#Checking missing values**

# %%
customers.isnull().sum()
# Out:
# Customer_ID      0
# Customer_Name    0
# Gender           0
# Age              0
# Email            0
# Phone            0
# Segment          0
# Join_Date        0
# City             0
# State            0
# dtype: int64

# %%
products.isnull().sum()
# Out:
# Product_ID       0
# Product_Name     0
# Brand            0
# Category         0
# Sub_Category     0
# Cost             0
# Selling_Price    0
# dtype: int64

# %%
orders.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Customer_ID       0
# Product_ID        0
# Category          0
# Sub_Category      0
# Product_Name      0
# Quantity          0
# Unit_Price        0
# Discount          0
# Sales             0
# Cost              0
# Profit            0
# Region            0
# State             0
# City              0
# Payment_Method    0
# Shipping_Mode     0
# Delivery_Days     0
# dtype: int64

# %% [markdown]
# **#Checking duplicate rows**

# %%
print("Customers:", customers.duplicated().sum())
print("Orders:", orders.duplicated().sum())
print("Products:", products.duplicated().sum())
# Out:
# Customers: 0
# Orders: 0
# Products: 0

# %% [markdown]
# **#Checking Unique values (Categorial Columns)**

# %%
customers.nunique()
# Out:
# Customer_ID      1000
# Customer_Name    1000
# Gender              2
# Age                48
# Email            1000
# Phone            1000
# Segment             3
# Join_Date         617
# City               10
# State               5
# dtype: int64

# %%
products.nunique()
# Out:
# Product_ID       99
# Product_Name     99
# Brand             3
# Category          3
# Sub_Category      9
# Cost             98
# Selling_Price    99
# dtype: int64

# %%
orders.nunique()
# Out:
# Order_ID          5000
# Order_Date         730
# Customer_ID        994
# Product_ID          99
# Category             3
# Sub_Category         9
# Product_Name        99
# Quantity             5
# Unit_Price          99
# Discount             5
# Sales             2083
# Cost               487
# Profit            2143
# Region               3
# State                5
# City                10
# Payment_Method       6
# Shipping_Mode        3
# Delivery_Days        7
# dtype: int64

# %% [markdown]
# **#Converting Date Columns**

# %%
customers["Join_Date"] = pd.to_datetime(customers["Join_Date"])

orders["Order_Date"] = pd.to_datetime(orders["Order_Date"])

# %%
customers.info()

orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer_ID    1000 non-null   str
#  1   Customer_Name  1000 non-null   str
#  2   Gender         1000 non-null   str
#  3   Age            1000 non-null   int64
#  4   Email          1000 non-null   str
#  5   Phone          1000 non-null   int64
#  6   Segment        1000 non-null   str
#  7   Join_Date      1000 non-null   datetime64[us]
#  8   City           1000 non-null   str
#  9   State          1000 non-null   str
# dtypes: datetime64[us](1), int64(2), str(7)
# memory usage: 78.3 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        5000 non-null   int64
#  1   Order_Date      5000 non-null   datetime64[us]
# ...

# %% [markdown]
# **#Verfying Unique IDs**

# %%
customers["Customer_ID"].nunique()
# Out:
# 1000

# %%
products["Product_ID"].nunique()
# Out:
# 99

# %%
orders["Order_ID"].nunique()
# Out:
# 5000

# %% [markdown]
# **#Creating Additional Columns**

# %%
orders["Order_Year"] = orders["Order_Date"].dt.year

orders["Order_Month"] = orders["Order_Date"].dt.month_name()

orders["Quarter"] = orders["Order_Date"].dt.quarter

orders["Day_Name"] = orders["Order_Date"].dt.day_name()

# %%
orders.head()
# Out:
#    Order_ID Order_Date Customer_ID Product_ID     Category   Sub_Category  \
# 0    100001 2023-04-20      C00677      P0025  Electronics     Headphones
# 1    100002 2023-05-24      C00499      P0011  Electronics  Mobile Phones
# 2    100003 2024-02-03      C00738      P0076    Furniture          Chair
# 3    100004 2023-01-17      C00316      P0064      Fashion          Jeans
# 4    100005 2023-05-02      C00346      P0093    Furniture           Sofa
#
#              Product_Name  Quantity  Unit_Price  Discount  ...  Region  \
# 0      Headphones Model 3         3     5264.53        15  ...    West
# 1  Mobile Phones Model 11         4     3020.64         5  ...    West
# 2          Chair Model 10         2     3369.65        15  ...   South
# 3           Jeans Model 9         5      854.56        15  ...   South
# 4            Sofa Model 5         1     4222.25        15  ...   North
#
#         State        City Payment_Method Shipping_Mode Delivery_Days  \
# ...

# %% [markdown]
# **#Checking Final Datasets Shape**

# %%
print(customers.shape)

print(orders.shape)

print(products.shape)
# Out:
# (1000, 10)
# (5000, 23)
# (99, 7)

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Sales by Category

# %%
category_sales = orders.groupby("Category")["Sales"].sum().sort_values(ascending=False)

plt.figure(figsize=(8,5))
plt.bar(category_sales.index, category_sales.values)

plt.title("Total Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # Monthly Sales Trend

# %%
orders["Order_Date"] = pd.to_datetime(orders["Order_Date"])
orders["Month"] = orders["Order_Date"].dt.to_period("M").astype(str)

monthly_sales = orders.groupby("Month")["Sales"].sum()

plt.figure(figsize=(10,5))
monthly_sales.plot(marker="o")

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.show()

# %% [markdown]
# # Top 10 Products

# %%
top_products = orders.groupby("Product_Name")["Sales"].sum().nlargest(10)

plt.figure(figsize=(10,6))
plt.barh(top_products.index, top_products.values)

plt.title("Top 10 Products by Sales")
plt.xlabel("Sales")
plt.ylabel("Product")

plt.show()

# %% [markdown]
# # Profit Distribution

# %%
plt.figure(figsize=(8,5))
plt.hist(orders["Profit"], bins=30)

plt.title("Profit Distribution")
plt.xlabel("Profit")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# # Sales by Payment Methods

# %%
payment_sales = orders.groupby("Payment_Method")["Sales"].sum()

plt.figure(figsize=(7,7))
plt.pie(
    payment_sales.values,
    labels=payment_sales.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Sales by Payment Method")

plt.show()

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **#Connecting  to postgresql**

# %%
from sqlalchemy import create_engine

# %%
username = "postgres"
password = "shreyash0910"
host = "localhost"
port = "5432"
database = "ecommerce_db"

engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

# %% [markdown]
# **#Uploading dataframes**

# %%
customers.to_sql("customers", engine, if_exists="replace", index=False)
products.to_sql("products", engine, if_exists="replace", index=False)
orders.to_sql("orders", engine, if_exists="replace", index=False)

print("Data Uploaded Successfully!")
# Out:
# Data Uploaded Successfully!
